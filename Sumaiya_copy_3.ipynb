# %% [markdown]
# # NeuralBeats: A Deep Learning Approach to Music Discovery

# %% [markdown]
# <img src="https://ongood.eu/wp-content/uploads/2018/01/musicbrain-814x520.jpg"
# alt="Image Description" width="814" height="auto">

# %% [markdown]
# # Business Understanding
#
# A new music streaming company **(NearalBeats)** is entering the competitive music industry, aiming to disrupt traditional recommendation systems. Current platforms primarily rely on genre and artist similarity, which often limits music discovery and personalization.
#
# To stand out, the company will leverage **Machine Learning (ML)** and **Deep Learning (DL)** to develop a context-aware, mood-driven, and user behavior-based recommendation engine. This system will enhance user experience, engagement, and retention by providing highly personalized music suggestions that adapt to mood, activity, and listening habits.

# %% [markdown]
# ## Problem statement
#
# The current music recommendation landscape is heavily reliant on genre, artist similarity, and historical listening patterns. This approach leads to redundant suggestions, reinforcing user **“bubbles”** rather than exposing them to diverse yet personally relevant music. Users seeking new experiences, mood-based playlists, or personalized discovery beyond their standard listening habits often find themselves stuck with repetitive recommendations.

# %% [markdown]
# ## Stakeholders
#
# **1. Users (Listeners)**
# - Benefit: More relevant and engaging music recommendations based on their mood, activities, and listening behavior.
# - Impact: Increased user satisfaction, retention, and engagement, leading to a better experience and less frustration with repetitive suggestions.
#
# **2. Music Artists & Creators**
# - Benefit: Better discovery and fairer exposure, allowing independent artists to reach new listeners beyond mainstream algorithms.
# - Impact: Helps emerging artists break into the industry and increases overall content diversity.
#
#
# **3. Business & Marketing Teams**
# - Benefit: A more engaging and personalized platform means higher user retention and increased revenue.
# - Impact: Strengthens Neural Beats’ market position, making it a strong competitor to Spotify and Apple Music.

# %% [markdown]
# ## Key Business Questions
#
# **1. User Experience & Personalization:**
#
# - How can Neural Beats improve music discovery and reduce repetitive recommendations?
# - How can we recommend songs based on mood, context, and listening behavior rather than just genre?
# - What features (e.g., valence, tempo, energy) are most effective for predicting user preferences?
#
# **2. Engagement & Retention:**
#
# - How can Neural Beats balance personalized recommendations with new music exploration?
# - What impact does context-aware music suggestions have on user session time and engagement?
# - How can we reduce churn rates and encourage long-term platform usage?
#
# **3. Technology & AI Strategy:**
#
# - Which ML/DL models are best suited for personalized recommendations?
# - How can Neural Beats use real-time data to dynamically adjust recommendations?
# - How can we ensure recommendations remain fair, unbiased, and diverse?
#
# **4.  Business & Revenue Growth:**
#
# - How do better recommendations impact subscription conversion rates?
# - Can personalized recommendations increase ad revenue and premium sign-ups?
# - What role does AI-driven discovery play in boosting music streaming consumption?

# %% [markdown]
# ## Project Objectives
#
# **1. Develop an AI-Driven Personalized Recommendation System**
#
# - Move beyond traditional genre-based recommendations.
# - Use audio features (danceability, energy, valence) to model user preferences.
# - Provide mood and context-aware song suggestions (e.g., workout, relaxation, focus).
#
# **2. Enhance Music Discovery & User Engagement**
#
# - Increase exposure to diverse and lesser-known tracks.
# - Balance personalization and exploration using AI.
# - Improve listener retention and satisfaction through adaptive playlists.
#
# **3. Leverage Machine Learning & Deep Learning for Advanced Personalization**
#
# - Use ML models to analyze track metadata and audio features.
# - Transition to DL models (neural networks, graph-based recommendations) for deeper personalization.
# - Continuously learn and adapt to user behavior in real-time.

# %% [markdown]
# Metrics of success

# %% [markdown]
# # Data Understanding
# To develop a next-generation AI-powered music recommendation system, Neural Beats relies on a well-structured dataset that captures track metadata, audio features, and popularity metrics. This section details the data source and relevance to ensure alignment with business objectives.

# %% [markdown]
# ## 1. Data source
# The dataset used for this project is the **Spotify Tracks Dataset**, sourced from **Kaggle**. It contains detailed information about Spotify tracks across 125 genres, along with associated audio features and popularity metrics.
#
# **Dataset Format**: CSV (Tabular)
#
# **Key Features Include:**
#
# **1.Track Metadata**: Song title, album, artist(s), genre, duration.
#
# **2.Audio Features**: Danceability, energy, loudness, tempo, and valence.
#
# **3.User Engagement**: Popularity score based on plays and recency
#
# **Feature Description**
#
# - **track_id:**
#  * The Spotify ID for the track
#
# - **artists:**
#  * The artists' names who performed the track. If there is more than one artist, they are separated by a ;
#
# - **album_name:**
#  * The album name in which the track appears
#
# - **track_name:**
#  * Name of the track
#
# - **popularity:**
#  * The popularity of a track is a value between 0 and 100, with 100 being the most popular.
#  * The popularity is calculated by algorithm and is based, in the most part, on the total number of plays the track has had and how recent those plays are.
#  * Generally speaking, songs that are being played a lot now will have a higher popularity than songs that were played a lot in the past.
#  * Duplicate tracks (e.g. the same track from a single and an album) are rated independently.
#  * Artist and album popularity is derived mathematically from track popularity.
#
# - **duration_ms:**
# * The track length in milliseconds
#
# - **explicit:**
#  * Whether or not the track has explicit lyrics (true = yes it does; false = no it does not OR unknown)
#
# - **danceability:**
#  * Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity.
#  * A value of 0.0 is least danceable and 1.0 is most danceable
#
# - **energy:**
#  * Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity.
#  * Typically, energetic tracks feel fast, loud, and noisy.
#  * For example, death metal has high energy, while a Bach prelude scores low on the scale
#
# - **key:**
#  * The key the track is in.
#  * Integers map to pitches using standard Pitch Class notation. E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on.
#  * If no key was detected, the value is -1
#
# - **loudness:**
#  * The overall loudness of a track in decibels (dB)
#  * A positive dB value indicates a signal is louder than the reference level.
#  * A negative dB value indicates a signal is quieter than the reference level.
#
# - **mode:**
#  * mode feature refers to the modality of the track, which indicates whether the track is in a major or minor key.
#  * Major mode (1) typically corresponds to more "happy," "bright," or "cheerful" sounds.
#  * Minor mode (0) typically corresponds to more "sad," "dark," or "serious" sounds.
#
# - **speechiness:**
#  * Speechiness detects the presence of spoken words in a track.
#  * The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value.
#  * Values above 0.66 describe tracks that are probably made entirely of spoken words.
#  * Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music.
#  * Values below 0.33 most likely represent music and other non-speech-like tracks
#
# - **acousticness:**
#  * A confidence measure from 0.0 to 1.0 of whether the track is acoustic.
#  * 1.0 represents high confidence the track is acoustic
#
# - **instrumentalness:**
#  * Predicts whether a track contains no vocals.
#  * "Ooh" and "aah" sounds are treated as instrumental in this context.
#  * Rap or spoken word tracks are clearly "vocal".
#  * The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content
#
# - **liveness:**
#  * Detects the presence of an audience in the recording.
#  * Higher liveness values represent an increased probability that the track was performed live.
#  * A value above 0.8 provides strong likelihood that the track is live
#
# - **valence:**
#  * A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track.
#  * Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry)
#
# - **tempo:**
# * The overall estimated tempo of a track in beats per minute (BPM).
#  * In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration
#
# - **time_signature:**
#  * An estimated time signature.
#  * The time signature (meter) is a notational convention to specify how many beats are in each bar (or measure).
#  * The time signature ranges from 3 to 7 indicating time signatures of 3/4, to 7/4.
#
# - **track_genre:**
#  * The genre in which the track belongs
#
# **The dataset provides a structured foundation for building personalized, mood-based music recommendations.**

# %% [markdown]
# ##  Why This Data is Useful
# - The Spotify Tracks Dataset is ideal for solving Neural Beats’ business problem because it includes rich audio and user interaction features that allow us to:
#
# **Build Personalized Recommendation Models**
# - Utilize audio features (e.g., danceability, energy, valence) to match user preferences.
# - Move beyond simple genre-based recommendations by considering song mood and context.
#
# **Improve Music Discovery & Engagement**
# - Predict emerging trends by analyzing song popularity over time.
# - Recommend undiscovered tracks based on listening behavior and similar song attributes.
#
# **Develop Context-Aware AI Models**
# - Suggest music based on user activity (e.g., workout, relaxation, focus).
# - Use tempo, acousticness, and valence to enhance mood-based recommendations.

# %% [markdown]
# ## Dataset Overview

# %% [markdown]
# ### Importing all the Libraries required for the project

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from scipy.stats import skew

from mpl_toolkits.mplot3d import Axes3D
from scipy.stats.mstats import winsorize


from sklearn.preprocessing import RobustScaler, StandardScaler, MinMaxScaler
from sklearn.preprocessing import LabelEncoder

from sklearn.utils import resample

from sklearn.decomposition import PCA

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from kneed import KneeLocator

import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from scipy.spatial.distance import pdist, cdist, squareform
from scipy.cluster.hierarchy import cophenet
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.manifold import TSNE

# %%
data=pd.read_csv('dataset.csv')

# %%
#view all columns
pd.set_option('display.max_columns',30)
#view the dataset
data.head(10)
# Out:
#    Unnamed: 0                track_id                               artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV                           Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A                          Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b                Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx                          Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K                      Chord Overstreet
# 5           5  01MVOl9KtVTNfFiBU9I7dc                          Tyrone Wells
# 6           6  6Vc5wAMmXdKIAM7WUoEb7N  A Great Big World;Christina Aguilera
# 7           7  1EzrEOXmMH3G43AXT1y7pA                            Jason Mraz
# 8           8  0IktbUcnAGrvD03AWnz3Q8             Jason Mraz;Colbie Caillat
# 9           9  7k9GuJYLp2AzqokyEdwEw2                        Ross Copperman
#
#                                           album_name  \
# 0                                             Comedy
# ...

# %%
data.tail()
# Out:
#         Unnamed: 0                track_id           artists  \
# 113995      113995  2C3TZjDRiAzdyViavDJ217     Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw     Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX     Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs  Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5     Cesária Evora
#
#                                                album_name  \
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                  track_name  popularity  duration_ms  explicit  danceability  \
# 113995  Sleep My Little Boy          21       384999     False         0.172
# 113996     Water Into Light          22       385000     False         0.174
# ...

# %%
# Checking columns
data.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
#get the shape of the dataset
data.shape
print(f"Our dataset has {data.shape[0]} rows and {data.shape[1]} columns")
# Out:
# Our dataset has 114000 rows and 21 columns

# %%
#checking for null values
data.isna().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
#checking for duplicates
data.duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
#checking datatypes
data.dtypes
# Out:
# Unnamed: 0            int64
# track_id             object
# artists              object
# album_name           object
# track_name           object
# popularity            int64
# duration_ms           int64
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# track_genre          object
# dtype: object

# %% [markdown]
# # Data Preparation
# This includes:
#  * creating a copy of our original dataset so that whatever we do won't affect the original dataset
#  * create a data profiling report to get the general overview of our data
#  * understand the data:
#      * explore the data
#      * manipulating column names for better readability
#      * dropping unnecessary columns
#  * identify missing values using df.isnull().sum() then fill the missing values appropriately if any,or drop them
#  * identify duplicates(df.duplicated() and remove them using df.drop_duplicated
#  * check the data types if they are appropriate for each column if not correct them
#  * standardize columns
#  * check and handle outliers appropriately
#  * create new features
#  * do final checks then save the cleaned data

# %% [markdown]
# ### Create a copy of the dataset
# We created a copy of our original dataset so that whatever we do won't affect the original dataset

# %%
#copy the dataset
df=data.copy(deep=True)

# %% [markdown]
# ### Create a Data Profiling report
# We create a data profiling report to get the general overview of our data

# %%
# # Import libraries
# from ydata_profiling import ProfileReport

# # Produce and save the profiling report
# profile = ProfileReport(df,title="Spotify Profile Report")
# profile.to_file("report.html")

# %%
#view the profiling report
# profile

# %% [markdown]
# ## 1. Data Cleaning

# %%
#get statistical summary
df.describe().T
# Out:
#                      count           mean            std     min  \
# Unnamed: 0        114000.0   56999.500000   32909.109681   0.000
# popularity        114000.0      33.238535      22.305078   0.000
# duration_ms       114000.0  228029.153114  107297.712645   0.000
# danceability      114000.0       0.566800       0.173542   0.000
# energy            114000.0       0.641383       0.251529   0.000
# key               114000.0       5.309140       3.559987   0.000
# loudness          114000.0      -8.258960       5.029337 -49.531
# mode              114000.0       0.637553       0.480709   0.000
# speechiness       114000.0       0.084652       0.105732   0.000
# acousticness      114000.0       0.314910       0.332523   0.000
# instrumentalness  114000.0       0.156050       0.309555   0.000
# liveness          114000.0       0.213553       0.190378   0.000
# valence           114000.0       0.474068       0.259261   0.000
# ...

# %%
#get statistical summary(for categorical columns)
df.describe(include='O').T
# Out:
#               count unique                         top  freq
# track_id     114000  89741      6S3JlDAGk3uu3NtZbPnuhS     9
# artists      113999  31437                 The Beatles   279
# album_name   113999  46589  Alternative Christmas 2022   195
# track_name   113999  73608             Run Rudolph Run   151
# track_genre  114000    114                    acoustic  1000

# %% [markdown]
# ### Column Manipulation
# We check:
#  * check column names to see if they are the same
#  * change the column names to lowercase
#  * rename column names to make them more undesrstandable
#  * remove whitespaces in the data and column names if any
#  * drop unnecessary column names

# %%
#checking the column names
df.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
#strip white spaces in values
df = df.apply(lambda col:col.str.strip() if col.dtype in ["object", "number", "category"] else col)

# %%
#drop the unnecessary columns
df = df.drop(columns=['Unnamed: 0'],errors='ignore')
#view  the dataset
df.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# ...

# %% [markdown]
# ### Handling missing values
# We want to identify if there is any missing values in our dataset and if so deal with them appropriately

# %%
#check for missing values
#df.isnull().sum()
mis = df.isna().any().sum()
if mis > 0:
    print(f'\nThere are {mis} missing values present in our data.')
else:
    print('There are no missing values in our data.')
mis
# Out:
# There are 3 missing values present in our data.
# 3

# %%
# drop the 1 missing value
df = df.dropna()
#check for missing values
#df.isnull().sum()
mis = df.isna().any().sum()
if mis > 0:
    print(f'\nThere are {mis} missing values present in our data.')
else:
    print('There are no missing values in our data.')
mis
# Out:
# There are no missing values in our data.
# 0

# %% [markdown]
# ### Duplicates
# First, we will try to identify if we have any duplicates, if any it'd be best to remove them

# %%
#checking for duplicates
dup = df.duplicated().sum()
if dup > 0:
    print(f'\nThere are {dup} duplicates present in our data.')
else:
    print('There are no duplicates in our data.')

dup
# Out:
# There are 450 duplicates present in our data.
# 450

# %%
df_filtered = df.drop_duplicates(subset=df.columns.difference(['track_genre']))

# %%
df_filtered.shape
# Out:
# (90460, 20)

# %%
#Most popular track_name in dataset
pop_track = df_filtered.sort_values(by='popularity', ascending=False).head(10)
pop_track
# Out:
#                      track_id                     artists  \
# 20001  3nqQXoyQOWXiESFLlDF1hG        Sam Smith;Kim Petras
# 51664  2tTmW7RDtMQtBk7m2rYeSw            Bizarrap;Quevedo
# 20008  4uUG5RXrOk84mYEfFvj3cK     David Guetta;Bebe Rexha
# 67356  5ww2BF9slyYgNOk37BlC4u               Manuel Turizo
# 67358  6Sq7ltF9Qa7SNFBsV5Cogx  Bad Bunny;Chencho Corleone
# 67359  1IHWl5LamUGEuP4ozKQSXZ                   Bad Bunny
# 20000  5IgjP7X4th6nMNDh4akUHb                 Chris Brown
# 67559  5Eax0qFko2dh7Rl2lYs3bx                   Bad Bunny
# 79000  4h9wh7iOZ0GGn8QVp4RAOB                 OneRepublic
# 81052  4LRPiXqCikLlN15c3yImP7                Harry Styles
#
#                                               album_name  \
# 20001                          Unholy (feat. Kim Petras)
# 51664              Quevedo: Bzrp Music Sessions, Vol. 52
# 20008                                    I'm Good (Blue)
# 67356                                         La Bachata
# ...

# %%
track_id_duplicates = df.duplicated(subset=['track_id']).sum()
print("Duplicates based on 'track_id':", track_id_duplicates)
# Out:
# Duplicates based on 'track_id': 24259

# %%
# Group by unique song attributes and merge genres
df_grouped = df.groupby(
    ['track_id', 'artists', 'album_name', 'track_name',
       'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']
)['track_genre'].apply(lambda x: ', '.join(x.unique())).reset_index()

df_grouped.head()
# Out:
#                  track_id                   artists       album_name  \
# 0  0000vdREvCVMxbQTkS888c                      Rill            Lolly
# 1  000CC8EParg64OmTxVnZ0p                 Glee Cast  Glee Love Songs
# 2  000Iz0K615UepwSJ5z2RE5  Paul Kalkbrenner;Pig&Dan                X
# 3  000RDCYioLteXcutOjeweY             Jordan Sandhu       Teeje Week
# 4  000qpdoc97IMTBvF8gwcpy          Paul Kalkbrenner             Zeit
#
#                                           track_name  popularity  duration_ms  \
# 0                                              Lolly          44       160725
# 1  It's All Coming Back To Me Now (Glee Cast Vers...          47       322933
# 2                      Böxig Leise - Pig & Dan Remix          22       515360
# 3                                         Teeje Week          62       190203
# 4                                               Tief          19       331240
#
#    explicit  danceability  energy  key  loudness  mode  speechiness  \
# ...

# %%
#Most popular track_name in dataset
pop_track=df_grouped.sort_values(by='popularity', ascending=False).head(10)
pop_track
# Out:
#                      track_id                     artists  \
# 44212  3nqQXoyQOWXiESFLlDF1hG        Sam Smith;Kim Petras
# 33608  2tTmW7RDtMQtBk7m2rYeSw            Bizarrap;Quevedo
# 69011  5ww2BF9slyYgNOk37BlC4u               Manuel Turizo
# 56914  4uUG5RXrOk84mYEfFvj3cK     David Guetta;Bebe Rexha
# 15091  1IHWl5LamUGEuP4ozKQSXZ                   Bad Bunny
# 75013  6Sq7ltF9Qa7SNFBsV5Cogx  Bad Bunny;Chencho Corleone
# 54454  4h9wh7iOZ0GGn8QVp4RAOB                 OneRepublic
# 61435  5IgjP7X4th6nMNDh4akUHb                 Chris Brown
# 60624  5Eax0qFko2dh7Rl2lYs3bx                   Bad Bunny
# 50400  4LRPiXqCikLlN15c3yImP7                Harry Styles
#
#                                               album_name  \
# 44212                          Unholy (feat. Kim Petras)
# 33608              Quevedo: Bzrp Music Sessions, Vol. 52
# 69011                                         La Bachata
# 56914                                    I'm Good (Blue)
# ...

# %%
df = df.drop_duplicates(subset=['track_id'], keep='first')
#Most popular track_name in dataset
pop_track = df.sort_values(by='popularity', ascending=False).head(10)
pop_track
# Out:
#                      track_id                     artists  \
# 20001  3nqQXoyQOWXiESFLlDF1hG        Sam Smith;Kim Petras
# 51664  2tTmW7RDtMQtBk7m2rYeSw            Bizarrap;Quevedo
# 20008  4uUG5RXrOk84mYEfFvj3cK     David Guetta;Bebe Rexha
# 67356  5ww2BF9slyYgNOk37BlC4u               Manuel Turizo
# 67358  6Sq7ltF9Qa7SNFBsV5Cogx  Bad Bunny;Chencho Corleone
# 67359  1IHWl5LamUGEuP4ozKQSXZ                   Bad Bunny
# 67559  5Eax0qFko2dh7Rl2lYs3bx                   Bad Bunny
# 20000  5IgjP7X4th6nMNDh4akUHb                 Chris Brown
# 79000  4h9wh7iOZ0GGn8QVp4RAOB                 OneRepublic
# 81052  4LRPiXqCikLlN15c3yImP7                Harry Styles
#
#                                               album_name  \
# 20001                          Unholy (feat. Kim Petras)
# 51664              Quevedo: Bzrp Music Sessions, Vol. 52
# 20008                                    I'm Good (Blue)
# 67356                                         La Bachata
# ...

# %%
data.shape
# Out:
# (114000, 21)

# %%
df.shape
# Out:
# (89740, 20)

# %%
for col in df.columns:
    duplicate_count = df.duplicated(subset=[col]).sum()
    print(f"Duplicates based on '{col}': {duplicate_count}")
# Out:
# Duplicates based on 'track_id': 0
# Duplicates based on 'artists': 58303
# Duplicates based on 'album_name': 43151
# Duplicates based on 'track_name': 16132
# Duplicates based on 'popularity': 89639
# Duplicates based on 'duration_ms': 39044
# Duplicates based on 'explicit': 89738
# Duplicates based on 'danceability': 88566
# Duplicates based on 'energy': 87657
# Duplicates based on 'key': 89728
# Duplicates based on 'loudness': 70260
# Duplicates based on 'mode': 89738
# Duplicates based on 'speechiness': 88251
# Duplicates based on 'acousticness': 84679
# Duplicates based on 'instrumentalness': 84394
# Duplicates based on 'liveness': 88018
# Duplicates based on 'valence': 87950
# Duplicates based on 'tempo': 44088
# Duplicates based on 'time_signature': 89735
# Duplicates based on 'track_genre': 89627

# %% [markdown]
# ### Data Types
# We check the datatypes to see if they are correctly placed if not change them

# %%
#check data types
df.dtypes
# Out:
# track_id             object
# artists              object
# album_name           object
# track_name           object
# popularity            int64
# duration_ms           int64
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# track_genre          object
# dtype: object

# %% [markdown]
# **converting mode to categorical**
# When you convert the mode column to a categorical data type, you are treating it as a discrete category with two possible values rather than a continuous or numeric variable.
#
# **This has a few advantages:**
#  * **Memory efficiency:**
#     * Storing categorical data is more memory-efficient than using regular integers or floats, especially when the values are limited (like 0 and 1 in the case of mode).
#
#  * **Clarity and Interpretation:**
#     * By converting mode to a categorical type, it is clearer that it represents a binary choice (major or minor) rather than just numbers.
#     * This helps when analyzing or visualizing the data, as it will be treated more appropriately by statistical models or machine learning algorithms.
#
#  * **Proper encoding:**
#
# Converting explicit column to the category data type, you're:
#  * optimizing memory usage
#  * improving performance for computational tasks
#  * making your dataset cleaner and more interpretable.

# %%
#changing to suitable datatypes
df['mode'] = df['mode'].astype('category')
df['explicit'] = df['explicit'].astype('category')
df['track_genre'] = df['track_genre'].astype('category')
#check datatypes again
df.dtypes
# Out:
# track_id              object
# artists               object
# album_name            object
# track_name            object
# popularity             int64
# duration_ms            int64
# explicit            category
# danceability         float64
# energy               float64
# key                    int64
# loudness             float64
# mode                category
# speechiness          float64
# acousticness         float64
# instrumentalness     float64
# liveness             float64
# valence              float64
# tempo                float64
# time_signature         int64
# track_genre         category
# dtype: object

# %% [markdown]
# ### Standardize columns
# Check for consistent format in our categorical by ensuring that they have consistent naming

# %%
 # Select categorical columns
categorical_cols = df.select_dtypes(include=["object","category"]).columns

for col in categorical_cols:
    print(f"Unique values in '{col}':\n", df[col].unique(), "\n")
# Out:
# Unique values in 'track_id':
#  ['5SuOikwiRyPMVoIQDJUgSV' '4qPNDBW1i3p13qLCt0Ki3A'
#  '1iJBSr7s7jYXzM8EGcbK5b' ... '6x8ZfSoqDjuNa5SVP5QjvX'
#  '2e6sXL2bYv4bSz6VTdnfLs' '2hETkH7cOfqmz3LqZDHZf5']
#
# Unique values in 'artists':
#  ['Gen Hoshino' 'Ben Woodward' 'Ingrid Michaelson;ZAYN' ...
#  'Cuencos Tibetanos Sonidos Relajantes'
#  'Bryan & Katie Torwalt;Brock Human' 'Jesus Culture']
#
# Unique values in 'album_name':
#  ['Comedy' 'Ghost (Acoustic)' 'To Begin Again' ...
#  '#20 Sueños Vividos - Música Intrumental Suave 2018 para Dormir Bien y Relajarse Profundamente'
#  'Frecuencias Álmicas en 432hz (Solo Piano)' 'Revelation Songs']
#
# Unique values in 'track_name':
#  ['Comedy' 'Ghost - Acoustic' 'To Begin Again' ... 'Water Into Light'
#  'Miss Perfumado' 'Barbincor']
#
# Unique values in 'explicit':
#  [False, True]
# Categories (2, bool): [False, True]
#
# Unique values in 'mode':
#  [0, 1]
# Categories (2, int64): [0, 1]
#
# Unique values in 'track_genre':
# ...

# %% [markdown]
# ### Handle outliers
# We will identify the outliers using box plots then decide on a strategy on how to deal with it depending on the outcome

# %%
# Select numerical columns
numeric_columns = df.select_dtypes(exclude=['object', 'bool', 'category'])

# Number of numerical columns
num_cols = len(numeric_columns.columns)

# Define number of rows and columns for subplots
rows = (num_cols // 3) + (num_cols % 3 > 0)  # Adjust rows based on number of columns
cols = min(3, num_cols)  # Max 3 columns per row

# Create subplots
fig, axes = plt.subplots(rows, cols, figsize=(15, rows * 4))

# Flatten axes array for easier iteration
axes = axes.flatten() if num_cols > 1 else [axes]

# Plot each boxplot
for i, col in enumerate(numeric_columns.columns):
    sns.boxplot(y=df[col], ax=axes[i], color='lightblue')
    axes[i].set_title(f'Box Plot of {col}')

# Remove empty subplots if any
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# there's plenty of outliers in duration_ms but we decided to keep them since they are sensitive columns

# %% [markdown]
# ### Checking skewness for numerical columns

# %%
# Select only numeric columns
numeric_columns = df.select_dtypes(include=['number'])

# Calculate skewness for each numeric column
skewness = numeric_columns.apply(skew).sort_values(ascending=False)

# Print skewness values
print(skewness)
# Out:
# duration_ms         11.072616
# speechiness          4.545759
# liveness             2.062058
# instrumentalness     1.563971
# acousticness         0.655761
# tempo                0.182741
# valence              0.127635
# popularity           0.070862
# key                 -0.000142
# danceability        -0.398285
# energy              -0.559983
# loudness            -1.959847
# time_signature      -3.998744
# dtype: float64

# %%
df.shape
# Out:
# (89740, 20)

# %%
# Apply log transformation for highly skewed right-skewed features
df['duration_ms'] = np.log1p(df['duration_ms'])
#df['duration_min'] = np.log1p(df['duration_min'])
df['speechiness'] = np.log1p(df['speechiness'])
df['liveness'] = np.log1p(df['liveness'])
df['instrumentalness'] = np.log1p(df['instrumentalness'])

# Apply square root transformation for moderate right skew
df['acousticness'] = np.sqrt(df['acousticness'])

# Apply square transformation for highly left-skewed features
df['loudness'] = df['loudness'] ** 2
df['time_signature'] = df['time_signature'] ** 2

# %%
# Check skewness again
# Select only numeric columns
numeric_columns = df.select_dtypes(include=['number'])

# Calculate skewness for each numeric column
skewness = numeric_columns.apply(skew).sort_values(ascending=False)

# Print skewness values
print(skewness)
# Out:
# loudness            4.378161
# speechiness         3.673145
# liveness            1.706271
# instrumentalness    1.487293
# tempo               0.182741
# acousticness        0.132611
# valence             0.127635
# popularity          0.070862
# key                -0.000142
# duration_ms        -0.323332
# danceability       -0.398285
# energy             -0.559983
# time_signature     -1.883433
# dtype: float64

# %%
df.shape
# Out:
# (89740, 20)

# %% [markdown]
# ### Outlier Removal

# %%
from scipy.stats.mstats import winsorize
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Winsorization (for highly skewed data)
winsorize_columns = ['loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'duration_ms']
for col in winsorize_columns:
    df[col] = winsorize(df[col], limits=[0.05, 0.05])  # Winsorize at 5th and 95th percentile

# IQR Method (Capping Outliers)
iqr_columns = ['danceability', 'valence', 'tempo']
for col in iqr_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df[col] = np.where(df[col] < lower_bound, lower_bound, df[col])
    df[col] = np.where(df[col] > upper_bound, upper_bound, df[col])

# Clipping (for bi-modal/multi-modal data)
clip_columns = ['popularity', 'key']
for col in clip_columns:
    lower_bound = df[col].quantile(0.01)
    upper_bound = df[col].quantile(0.99)
    df[col] = np.clip(df[col], lower_bound, upper_bound)

# Boxplot Visualization
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

fig, axes = plt.subplots(len(numeric_columns), 1, figsize=(10, len(numeric_columns) * 3))

for i, col in enumerate(numeric_columns):
    sns.boxplot(y=df[col], ax=axes[i], color='lightblue')
    axes[i].set_title(f'Box Plot of {col}')

# Remove empty subplots
for j in range(i + 1, len(axes)):
    if j < len(fig.axes):
        fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
df.shape
# Out:
# (89740, 20)

# %%
df.duration_ms
# Out:
# 0         12.348730
# 1         11.915794
# 2         12.258793
# 3         12.215696
# 4         12.200326
#             ...
# 113995    12.860999
# 113996    12.861001
# 113997    12.511596
# 113998    12.556356
# 113999    12.395978
# Name: duration_ms, Length: 89740, dtype: float64

# %%
#convert duration_ms to minutes
df['duration_min'] = df['duration_ms'] / 60000

# %% [markdown]
# ### Final Checks
# After cleaning,we are reviewing the dataframe using df.head() and df.info() to ensure that the cleaning steps have been applied correctly

# %%
#view the data
df.head(10)
# Out:
#                  track_id                               artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV                           Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A                          Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b                Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx                          Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K                      Chord Overstreet
# 5  01MVOl9KtVTNfFiBU9I7dc                          Tyrone Wells
# 6  6Vc5wAMmXdKIAM7WUoEb7N  A Great Big World;Christina Aguilera
# 7  1EzrEOXmMH3G43AXT1y7pA                            Jason Mraz
# 8  0IktbUcnAGrvD03AWnz3Q8             Jason Mraz;Colbie Caillat
# 9  7k9GuJYLp2AzqokyEdwEw2                        Ross Copperman
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# ...

# %%
df.track_genre.value_counts()
# Out:
# track_genre
# acoustic     1000
# alt-rock      999
# tango         999
# ambient       999
# afrobeat      999
#              ...
# metal         232
# punk          226
# house         210
# indie         134
# reggaeton      74
# Name: count, Length: 113, dtype: int64

# %%
#view the dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89740 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          89740 non-null  object
#  1   artists           89740 non-null  object
#  2   album_name        89740 non-null  object
#  3   track_name        89740 non-null  object
#  4   popularity        89740 non-null  int64
#  5   duration_ms       89740 non-null  float64
#  6   explicit          89740 non-null  category
#  7   danceability      89740 non-null  float64
#  8   energy            89740 non-null  float64
#  9   key               89740 non-null  int64
#  10  loudness          89740 non-null  float64
#  11  mode              89740 non-null  category
#  12  speechiness       89740 non-null  float64
#  13  acousticness      89740 non-null  float64
#  14  instrumentalness  89740 non-null  float64
#  15  liveness          89740 non-null  float64
# ...

# %%
#reset index
df.reset_index(drop=True, inplace=True)
#review the dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89740 entries, 0 to 89739
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          89740 non-null  object
#  1   artists           89740 non-null  object
#  2   album_name        89740 non-null  object
#  3   track_name        89740 non-null  object
#  4   popularity        89740 non-null  int64
#  5   duration_ms       89740 non-null  float64
#  6   explicit          89740 non-null  category
#  7   danceability      89740 non-null  float64
#  8   energy            89740 non-null  float64
#  9   key               89740 non-null  int64
#  10  loudness          89740 non-null  float64
#  11  mode              89740 non-null  category
#  12  speechiness       89740 non-null  float64
#  13  acousticness      89740 non-null  float64
#  14  instrumentalness  89740 non-null  float64
#  15  liveness          89740 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre', 'duration_min'],
#       dtype='object')

# %% [markdown]
# # 2. EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ## 2.1. UNIVERIATE ANALYSIS

# %%
num_columns = df[['popularity','danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_min']]
categorical_cols=df[['explicit','mode']]

# %% [markdown]
# ### 2.1.1. Subplot Numerical columns

# %%
#plotting the distribution of numerical columns
plt.figure(figsize=(20, 20))
for i, col in enumerate(num_columns, 1):
    plt.subplot(4, 4, i)
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.1.2. Pie Chart Distribution of Categorical columns

# %%
#plotting the distribution of categorical columns

# Define a high-contrast color palette manually
high_contrast_colors = [
    "#e41a1c", "#377eb8", "#4daf4a", "#984ea3", "#ff7f00",
    "#ffff33", "#a65628", "#f781bf", "#999999"
]

# Adjust figure size
plt.figure(figsize=(20, 20))

# Loop through categorical columns and create pie charts
for i, col in enumerate(categorical_cols, 1):
    plt.subplot(4, 4, i)  # Create a 4x4 grid of subplots
    value_counts = df[col].value_counts()  # Count occurrences

    # Select a subset of colors for current chart
    colors = high_contrast_colors[:len(value_counts)]

    plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%',
            startangle=90, colors=colors)
    plt.title(f'Distribution of {col}')  # Title for each subplot

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.1.3. Bar Plot (Total Artist)

# %%
#total number of artists
total_artists = df['artists'].unique()
print(f'The total number of artists in our dataset is: {len(total_artists)}')

#plotting using barplot
plt.figure(figsize=(10, 10))
df['artists'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Artists with the Most Songs')
plt.show()
# Out:
# The total number of artists in our dataset is: 31437

# %% [markdown]
# ### 2.1.4. Bar Plot (Genre count)

# %%
#total number of genres
total_genres = df['track_genre'].unique()
print(f'The total number of genres in our dataset is: {len(total_genres)}')

#plotting
plt.figure(figsize=(10, 10))
df['track_genre'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Genres with the Most Songs')
plt.show()
# Out:
# The total number of genres in our dataset is: 113

# %% [markdown]
# ## 2.2. BIVARIATE ANALYSIS

# %% [markdown]
# bivariate - genre_duration,genre_popularity,gerne_valence,genre_tempo

# %% [markdown]
# ### 2.2.1. PAIR-PLOTS FOR EACH FEATURE

# %%
df.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre', 'duration_min'],
#       dtype='object')

# %% [markdown]
# ### 2.2.2. Bar Plot (Average Track_genre by duration_min)

# %%
#mean duration for each genre and get the top 10
df_genre_duration = df.groupby('track_genre')['duration_min'].mean().sort_values(ascending=False).head(10)

# Plot the bar chart
plt.figure(figsize=(10, 6))
df_genre_duration.plot(kind='bar', color='skyblue', edgecolor='black')

# Improve visualization
plt.title('Top 10 Genres by Average Song Duration')
plt.ylabel('Average Duration (minutes)')
plt.xlabel('Genre')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add grid for better readability
plt.show()

# %% [markdown]
# ### 2.2.3. Bar Plot (Track_genre and Popularity)

# %%
#plotting most popular genres
df_genre_popularity = df.groupby('track_genre', observed=True)['popularity'].mean().sort_values(ascending=False).head(10)
print('Top 10 Most Popular Genres:')
print(df_genre_popularity)
# Out:
# Top 10 Most Popular Genres:
# track_genre
# k-pop       59.302402
# pop-film    59.094479
# metal       56.353448
# chill       53.716049
# sad         51.088652
# latino      50.824121
# grunge      50.587007
# indian      49.750341
# anime       48.771859
# emo         48.427039
# Name: popularity, dtype: float64

# %%
# Plot the bar chart
plt.figure(figsize=(10, 6))
df_genre_popularity.plot(kind='bar', color='lightcoral', edgecolor='black')

# Improve visualization
plt.title('Top 10 Most Popular Genres')
plt.ylabel('Average Popularity')
plt.xlabel('Genre')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add grid for better readability
plt.show()

# %% [markdown]
# ### 2.2.4. Bar Plot (Track_genre and Valence)

# %%
#genre by valence
df_genre_valence = df.groupby('track_genre', observed=True)['valence'].mean().sort_values(ascending=False).head(10)
print('Top 10 Genres by Valence:')
print(df_genre_valence)
# Out:
# Top 10 Genres by Valence:
# track_genre
# salsa         0.813806
# forro         0.760499
# rockabilly    0.737709
# ska           0.719166
# samba         0.705054
# afrobeat      0.698475
# pagode        0.697245
# children      0.693671
# kids          0.681698
# disco         0.679275
# Name: valence, dtype: float64

# %%
#plotting charts
plt.figure(figsize=(10, 6))
df_genre_valence.plot(kind='bar', color='lightgreen', edgecolor='black')

# Improve visualization
plt.title('Top 10 Genres by Valence')
plt.ylabel('Average Valence')
plt.xlabel('Genre')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add grid for better readability
plt.show()

# %% [markdown]
# ### 2.2.5. Bar Plot (Track_genre and Danceability)

# %%
#genre by danceability
df_genre_danceability = df.groupby('track_genre', observed=True)['danceability'].mean().sort_values(ascending=False).head(10)
print('Top 10 Genres by Danceability:')
print(df_genre_danceability)
# Out:
# Top 10 Genres by Danceability:
# track_genre
# kids              0.778808
# chicago-house     0.766240
# latino            0.755487
# reggaeton         0.743284
# minimal-techno    0.732045
# dancehall         0.731430
# hip-hop           0.730052
# reggae            0.728457
# latin             0.726954
# detroit-techno    0.722664
# Name: danceability, dtype: float64

# %%
#plotting
plt.figure(figsize=(10, 6))
df_genre_danceability.plot(kind='bar', color='gold', edgecolor='black')

# Improve visualization
plt.title('Top 10 Genres by Danceability')
plt.ylabel('Average Danceability')
plt.xlabel('Genre')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add grid for better readability
plt.show()

# %% [markdown]
# ### 2.2.6. Bar Plot (Track_genre and Tempo)

# %%
#genre by tempo
df_genre_tempo = df.groupby('track_genre', observed=True)['tempo'].mean().sort_values(ascending=False).head(10)
print('Top 10 Genres by Tempo:')
print(df_genre_tempo)
# Out:
# Top 10 Genres by Tempo:
# track_genre
# drum-and-bass    155.151446
# happy            152.952974
# hardstyle        146.688615
# forro            140.350656
# j-idol           136.068937
# trance           135.270682
# power-pop        134.499817
# punk             134.137451
# dubstep          133.351535
# breakbeat        133.049973
# Name: tempo, dtype: float64

# %%
#plotting
plt.figure(figsize=(10, 6))
df_genre_tempo.plot(kind='bar', color='orange', edgecolor='black')
# Improve visualization
plt.title('Top 10 Genres by Tempo')
plt.ylabel('Average Tempo')
plt.xlabel('Genre')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add grid for better readability
plt.show()

# %% [markdown]
# ### 2.2.6. Bar Plot (Artist by Popularity)

# %%
#artist by popularity
df_artist_popularity = df.groupby('artists', observed=True)['popularity'].mean().sort_values(ascending=False).head(10)
print('Top 10 Artists by Popularity:')
print(df_artist_popularity)
# Out:
# Top 10 Artists by Popularity:
# artists
# Mora;Feid                    78.0
# French Montana;Swae Lee      78.0
# Drake;21 Savage              78.0
# XXXTENTACION;Trippie Redd    78.0
# Drake;Travis Scott           78.0
# Capital Cities               78.0
# Olivia Rodrigo               78.0
# Sam Smith;Kim Petras         78.0
# Lewis Capaldi                78.0
# Liana Flores                 78.0
# Name: popularity, dtype: float64

# %%
#plotting
plt.figure(figsize=(10, 6))
df_artist_popularity.plot(kind='bar', color='purple', edgecolor='black')

# Improve visualization
plt.title('Top 10 Artist by Popularity')
plt.ylabel('Average Popularity')
plt.xlabel('Artist')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add grid for better readability
plt.show()

# %% [markdown]
# # 3. MULTIVARIATE

# %% [markdown]
# ## 3.1. correlation heatmap between numerical features

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(num_columns.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# The color gradient represents the strength and direction of correlation:
#
# Red → Strong positive correlation (+1)
#
# Blue → Strong negative correlation (-1)
#
# White/Neutral Colors → Weak or no correlation (0)
#
# Key Interpretations:
#
# 1. energy and loudness (0.76) → Strong positive correlation
#
#     Louder songs tend to have higher energy.
#
# 2. acousticness and energy (-0.73) → Strong negative correlation
#
#     Acoustic songs tend to have lower energy levels.
#
# 3. instrumentalness and loudness (-0.43) → Moderate negative correlation
#
#     More instrumental tracks tend to be quieter.
#
# 4. danceability and valence (0.48) → Moderate positive correlation
#
#     Happier songs (high valence) are more danceable.
#
# 5. popularity and other features
#
#     **Popularity has weak correlations (close to 0) with most features, meaning song attributes like energy, danceability, or duration do not strongly determine a song’s popularity.**

# %% [markdown]
# ## 3.2. Pairplots (Numerical and categorical colums with hue track_genre)

# %%
# #pairplots
# sns.pairplot(num_columns)
# plt.show()

# %%
#pairplots of categorical columns
# sns.pairplot(df, hue="track_genre", diag_kind="kde", palette="coolwarm")
# plt.show()

# %% [markdown]
# ## 3.3. 3D Scatter Plot (Popularity, Liveness, and Tempo)

# %%
# Get Top 10 Artists by Average Popularity
top_artists = df.groupby('artists')['popularity'].mean().nlargest(10).index
df_top_artists = df[df['artists'].isin(top_artists)]

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
for artist in top_artists:
    subset = df_top_artists[df_top_artists['artists'] == artist]
    ax.scatter(subset['popularity'], subset['instrumentalness'], subset['tempo'], label=artist, s=50)

ax.set_xlabel('Popularity')
ax.set_ylabel('Instrumentalness')
ax.set_zlabel('Tempo')
ax.set_title("Top 10 Artists: Popularity vs Liveness vs Tempo")
ax.legend(loc='best')

plt.show()

# %%
# Select top 10 track_genres based on popularity
top10_track_genres = df.nlargest(10, 'popularity')

# Set figure size
plt.figure(figsize=(12, 6))

# Define colors for better visibility
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

# Create bar plots for each feature
bar_width = 0.2  # Adjust for better spacing
x = range(len(top10_track_genres['track_genre']))  # X-axis positions

for i, feature in enumerate(['valence', 'energy', 'danceability', 'acousticness']):
    plt.bar([pos + i * bar_width for pos in x], top10_track_genres[feature], 
            width=bar_width, label=feature, color=colors[i])

# Set labels and title
plt.xticks([pos + bar_width * 1.5 for pos in x], top10_track_genres['track_genre'], rotation=45)
plt.xlabel('Track Genre')
plt.ylabel('Feature Values')
plt.title('Comparison of Features Across Top 10 track_genre')
plt.legend()
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# # 3. Data Preprocessing

# %% [markdown]
# ### 3.1. Feature Engineering

# %%
# Ensure 'mode' is numeric
df['mode'] = pd.to_numeric(df['mode'], errors='coerce')

# Feature Interactions
df['valence_dance'] = df['valence'] * df['danceability']
df['energy_tempo'] = df['energy'] * df['tempo']
df['dance_energy'] = df['danceability'] * df['energy']
df['speech_acoustic'] = df['speechiness'] * df['acousticness']
df['loudness_energy'] = df['loudness'] * df['energy']
df['valence_mode'] = df['valence'] * df['mode']  # Now 'mode' is numeric

# Log Transformations
df['log_duration'] = np.log1p(df['duration_min'])
df['log_loudness'] = np.log1p(df['loudness'].abs())

# Tempo Categorization
df['tempo_category'] = pd.cut(df['tempo'], bins=[0, 80, 120, 180, np.inf],
                              labels=['slow', 'medium', 'fast', 'very fast'])

print(df.columns)  # Verify new columns exist
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre', 'duration_min',
#        'valence_dance', 'energy_tempo', 'dance_energy', 'speech_acoustic',
#        'loudness_energy', 'valence_mode', 'log_duration', 'log_loudness',
#        'tempo_category'],
#       dtype='object')

# %%
df.head(5)
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms explicit  danceability  \
# 0                      Comedy          73    12.348730    False         0.676
# 1            Ghost - Acoustic          55    11.915794    False         0.420
# 2              To Begin Again          57    12.258793    False         0.438
# ...

# %%
print(df['loudness'].describe())
# Out:
# count    89740.000000
# mean        85.863179
# std         90.127504
# min          9.000000
# 25%         26.091664
# 50%         51.624225
# 75%        106.548845
# max        355.775044
# Name: loudness, dtype: float64

# %%
print(df[df['loudness'] > 0])
# Out:
#                      track_id                 artists  \
# 0      5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1      4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2      1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3      6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4      5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...                       ...                     ...
# 89735  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 89736  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 89737  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 89738  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 89739  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                               album_name  \
# 0                                                 Comedy
# 1                                       Ghost (Acoustic)
# 2                                         To Begin Again
# 3      Crazy Rich Asians (Original Motion Picture Sou...
# ...

# %%
df['loudness'].describe()
# Out:
# count    89740.000000
# mean        85.863179
# std         90.127504
# min          9.000000
# 25%         26.091664
# 50%         51.624225
# 75%        106.548845
# max        355.775044
# Name: loudness, dtype: float64

# %%
df['loudness'] = df['loudness'] - 300  # Adjust to bring values closer to real dB levels

# %%
#df['loudness'] = df['loudness'] - df['loudness'].max()

# %%
print(df['loudness'].describe())
# Out:
# count    89740.000000
# mean      -214.136821
# std         90.127504
# min       -291.000000
# 25%       -273.908336
# 50%       -248.375775
# 75%       -193.451155
# max         55.775044
# Name: loudness, dtype: float64

# %%
df.to_csv('cleaned_data.csv', index = False)

# %% [markdown]
# ### PCA for Dimensionality reduction

# %% [markdown]
# ### Label Encoding

# %%
df = pd.read_csv('cleaned_data.csv')
df.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73    12.348730     False
# 1            Ghost - Acoustic          55    11.915794     False
# 2              To Begin Again          57    12.258793     False
# 3  Can't Help Falling In Love          71    12.215696     False
# ...

# %%
# encoding explicit, tempo_cat, track_genre
# Encode 'explicit' (True/False → 1/0)
df['explicit'] = df['explicit'].astype(int)

# Encode 'tempo_category' using LabelEncoder
encoder = LabelEncoder()
df['tempo_category'] = encoder.fit_transform(df['tempo_category'])
df['track_genre_encoded'] = encoder.fit_transform(df['track_genre'])

# Check the transformed values
df[['explicit', 'tempo_category', 'track_genre_encoded']].head()
# Out:
#    explicit  tempo_category  track_genre_encoded
# 0         0               1                    0
# 1         0               2                    0
# 2         0               2                    0
# 3         0               3                    0
# 4         0               1                    0

# %%
# Encode categorical columns
for col in df.select_dtypes(include=['object']).columns:
    df[col] = LabelEncoder().fit_transform(df[col])

# Drop missing values
df = df.dropna()

# %%
df.head()
# Out:
#    track_id  artists  album_name  track_name  popularity  duration_ms  \
# 0     62845    10357        8100       11741          73    12.348730
# 1     55667     3287       14796       22528          55    11.915794
# 2     19766    12397       39162       60774          57    12.258793
# 3     77941    14839        8580        9580          71    12.215696
# 4     68241     5255       16899       25689          78    12.200326
#
#    explicit  danceability  energy  key    loudness  mode  speechiness  \
# 0         0         0.676  0.4610    1 -254.491484     0     0.133656
# 1         0         0.420  0.1660    1   -2.954775     1     0.073529
# 2         0         0.438  0.3590    0 -205.249244     1     0.054204
# 3         0         0.266  0.0596    0   42.805225     1     0.035657
# 4         0         0.618  0.4430    2 -206.278239     1     0.051263
#
#    acousticness  instrumentalness  ...  valence    tempo  time_signature  \
# ...

# %%
# 1. Define feature groups based on their distribution
standard_scaler_features = ['tempo']
minmax_scaler_features = ['popularity', 'loudness']
robust_scaler_features = ['duration_ms', 'energy_tempo', 'loudness_energy']

# %%
print(df[standard_scaler_features + minmax_scaler_features + robust_scaler_features].dtypes)
# Out:
# tempo              float64
# popularity           int64
# loudness           float64
# duration_ms        float64
# energy_tempo       float64
# loudness_energy    float64
# dtype: object

# %%
df['popularity'].value_counts()
# Out:
# popularity
# 0     9447
# 21    2271
# 22    2258
# 20    2058
# 23    2038
#       ...
# 73     262
# 75     234
# 4      231
# 76     208
# 77     173
# Name: count, Length: 79, dtype: int64

# %%
print(df['mode'].isna().sum())  # Check for NaNs
#df['mode'].fillna(df['mode'].mode()[0], inplace=True)  # Fill with most common value if needed
# Out:
# 0

# %%
# Convert 'popularity' to float64 to ensure consistency
df['popularity'] = df['popularity'].astype(float)

# 2. Apply respective scalers
scalers = {
    'standard': StandardScaler(),
    'minmax': MinMaxScaler(),
    'robust': RobustScaler()
}

df_scaled = df.copy()  # Keep a copy of original dataset

# Standard Scaling
df_scaled[standard_scaler_features] = scalers['standard'].fit_transform(df[standard_scaler_features])

# MinMax Scaling
df_scaled[minmax_scaler_features] = scalers['minmax'].fit_transform(df[minmax_scaler_features])

# Robust Scaling
df_scaled[robust_scaler_features] = scalers['robust'].fit_transform(df[robust_scaler_features])

# 3. Check summary statistics after scaling
print(df_scaled.describe())
# Out:
#            track_id       artists    album_name    track_name    popularity  \
# count  89740.000000  89740.000000  89740.000000  89740.000000  89740.000000
# mean   44869.500000  15743.452318  22666.406630  36567.906998      0.425113
# std    25905.850916   9049.356361  13473.658482  21072.953476      0.262640
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%    22434.750000   8095.000000  10937.750000  18472.750000      0.243590
# 50%    44869.500000  15613.000000  22527.000000  36406.000000      0.423077
# 75%    67304.250000  23501.250000  34357.250000  54751.250000      0.628205
# max    89739.000000  31436.000000  46588.000000  73607.000000      1.000000
#
#         duration_ms      explicit  danceability        energy           key  \
# count  89740.000000  89740.000000  89740.000000  89740.000000  89740.000000
# mean      -0.001669      0.085848      0.562372      0.634458      5.283530
# ...

# %%
df_scaled.head(5)
# Out:
#    track_id  artists  album_name  track_name  popularity  duration_ms  \
# 0     62845    10357        8100       11741    0.935897     0.184854
# 1     55667     3287       14796       22528    0.705128    -0.837347
# 2     19766    12397       39162       60774    0.730769    -0.027496
# 3     77941    14839        8580        9580    0.910256    -0.129251
# 4     68241     5255       16899       25689    1.000000    -0.165541
#
#    explicit  danceability  energy  key  loudness  mode  speechiness  \
# 0         0         0.676  0.4610    1  0.105280     0     0.133656
# 1         0         0.420  0.1660    1  0.830640     1     0.073529
# 2         0         0.438  0.3590    0  0.247281     1     0.054204
# 3         0         0.266  0.0596    0  0.962599     1     0.035657
# 4         0         0.618  0.4430    2  0.244313     1     0.051263
#
#    acousticness  instrumentalness  ...  valence     tempo  time_signature  \
# ...

# %%
for col in df_scaled.select_dtypes(include=['object']).columns:
    print(f"{col}: {df_scaled[col].unique()}")

# %%
# droping artist column from our dataframe
df_scaled = df_scaled.drop(columns=['artists'], axis=1)

# %%
df_scaled = df_scaled.drop(columns=['track_genre'])

# %%
# decalare the PCA
pca = PCA(n_components=2)
# fit and transform the PCA to our data
pca_transformed = pca.fit_transform(df_scaled)

# %%
print(df_scaled.dtypes)
# Out:
# track_id                 int32
# album_name               int32
# track_name               int32
# popularity             float64
# duration_ms            float64
# explicit                 int32
# danceability           float64
# energy                 float64
# key                      int64
# loudness               float64
# mode                     int64
# speechiness            float64
# acousticness           float64
# instrumentalness       float64
# liveness               float64
# valence                float64
# tempo                  float64
# time_signature           int64
# duration_min           float64
# valence_dance          float64
# energy_tempo           float64
# dance_energy           float64
# speech_acoustic        float64
# loudness_energy        float64
# valence_mode           float64
# log_duration           float64
# log_loudness           float64
# tempo_category           int32
# track_genre_encoded      int32
# dtype: object

# %%
df['track_genre_encoded'].value_counts()
# Out:
# track_genre_encoded
# 0      1000
# 2       999
# 107     999
# 4       999
# 1       999
#        ...
# 71      232
# 85      226
# 53      210
# 56      134
# 89       74
# Name: count, Length: 113, dtype: int64

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Clustering Using K-Means
# - Clustering the dataset to find the mood of each track using K-Means clustering

# %% [markdown]
# ### Elbow method

# %%
# running kmeans for different cluster values
wcss = []
k_values = range(2,11)

for k in k_values:
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state=42)
    kmeans.fit(pca_transformed)
    wcss.append(kmeans.inertia_)

# Use KneeLocator to find the optimal k
knee = KneeLocator(k_values, wcss, curve="convex", direction="decreasing")

# %%
# Plot Elbow Method
plt.figure(figsize=(8,5))
plt.plot(k_values, wcss, marker='o', linestyle='--')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("WCSS")
plt.title("Elbow Method for Optimal k")
plt.axvline(x=knee.elbow, color='r', linestyle='--', label=f'Optimal k: {knee.elbow}')
plt.legend()
plt.show()

# %%
print(f"Optimal number of clusters (Elbow Method): {knee.elbow}")
# Out:
# Optimal number of clusters (Elbow Method): 4

# %% [markdown]
# ### Silhouette method

# %%
sampled_data = resample(pca_transformed, n_samples=10000, random_state=42)
silhouette_scores = []

for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state=42, n_init=10)
    kmeans.fit(sampled_data)
    score = silhouette_score(sampled_data, kmeans.labels_)
    silhouette_scores.append(score)

# %%
# Plot Silhouette Scores
plt.figure(figsize=(8,5))
plt.plot(range(2, 11), silhouette_scores, marker='o', linestyle='--')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Method for Optimal k")
plt.show()

# %%
# Clustering using K-means
for k in [2, 4]:
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state=42)
    clusters = kmeans.fit_predict(pca_transformed)

    plt.figure(figsize=(6,6))
    plt.scatter(pca_transformed[:, 0], pca_transformed[:, 1], c=clusters, cmap='viridis', s=50)
    plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],
                s=200, c='red', marker='X', label='Centroids')

    plt.title(f'K-Means Clustering (K={k})')
    plt.legend()
    plt.show()

# %% [markdown]
# ## Hierarchical Agglomerative Clustering

# %%
from umap import UMAP

# Reduce dimensionality
umap = UMAP(n_components=5, n_neighbors=30, min_dist=0.05, random_state=42)
umap_reduced = umap.fit_transform(pca_transformed)

# %%
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import linkage, fcluster, dendrogram, cophenet
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
from scipy.spatial.distance import cdist

# %%
# Define Batch Processing Functions
def batch_hac_clustering(data, batch_size, cluster_range):
    """
    Perform HAC clustering in batches and compute evaluation metrics.
    
    Parameters:
    - data: np.array, dataset to cluster
    - batch_size: int, size of each batch
    - cluster_range: list, range of cluster values to evaluate
    
    Returns:
    - Dictionary with silhouette scores, DBI, CHI, WCSS, CCC
    """
    n_samples = data.shape[0]
    indices = np.random.permutation(n_samples)  # Shuffle data
    silhouette_scores = {k: [] for k in cluster_range}
    dbi_scores = {k: [] for k in cluster_range}
    ch_scores = {k: [] for k in cluster_range}
    wcss = {k: [] for k in cluster_range}
    ccc_scores = []

    for i in range(0, n_samples, batch_size):
        print(f"Processing batch {i // batch_size + 1}/{n_samples // batch_size + 1}")
        batch_data = data[indices[i: i + batch_size]]
        
        # Perform HAC clustering
        Z = linkage(batch_data, method='average')
        
        # Compute CCC (Cophenetic Correlation Coefficient)
        coph_corr, _ = cophenet(Z, pdist(batch_data))
        ccc_scores.append(coph_corr)

        for k in cluster_range:
            labels = fcluster(Z, k, criterion='maxclust')

            # Silhouette Score
            if len(set(labels)) > 1:  # Avoid errors from single-cluster cases
                silhouette_scores[k].append(silhouette_score(batch_data, labels))

            # Davies-Bouldin Index (DBI)
            dbi_scores[k].append(davies_bouldin_score(batch_data, labels))

            # Calinski-Harabasz Index (CHI)
            ch_scores[k].append(calinski_harabasz_score(batch_data, labels))

            # Within-Cluster Sum of Squares (WCSS)
            wcss_value = 0
            for label in np.unique(labels):  
                cluster_points = batch_data[labels == label]  # Get points in cluster
                centroid = np.mean(cluster_points, axis=0)  # Compute centroid
                wcss_value += np.sum(np.linalg.norm(cluster_points - centroid, axis=1) ** 2)  # Sum squared distances

            wcss[k].append(wcss_value)

    return {
        "silhouette": {k: np.mean(v) for k, v in silhouette_scores.items()},
        "dbi": {k: np.mean(v) for k, v in dbi_scores.items()},
        "chi": {k: np.mean(v) for k, v in ch_scores.items()},
        "wcss": {k: np.mean(v) for k, v in wcss.items()},
        "ccc": np.mean(ccc_scores)
    }

# %%
# Run Batch Clustering
batch_size = 5000  # Adjust based on available memory
cluster_range = range(2, 15)  # Try clusters from 2 to 14

metrics = batch_hac_clustering(umap_reduced, batch_size, cluster_range)
# Out:
# Processing batch 1/18
# Processing batch 2/18
# Processing batch 3/18
# Processing batch 4/18
# Processing batch 5/18
# Processing batch 6/18
# Processing batch 7/18
# Processing batch 8/18
# Processing batch 9/18
# Processing batch 10/18
# Processing batch 11/18
# Processing batch 12/18
# Processing batch 13/18
# Processing batch 14/18
# Processing batch 15/18
# Processing batch 16/18
# Processing batch 17/18
# Processing batch 18/18

# %% [markdown]
# ## Visualize the Metrics

# %% [markdown]
# ### 1. Silhouette Score Plot

# %%
plt.figure(figsize=(8, 5))
plt.plot(list(metrics["silhouette"].keys()), list(metrics["silhouette"].values()), marker="o", linestyle="dashed", color="blue")
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score vs. Number of Clusters (Batch Processing)")
plt.show()

# %% [markdown]
# ### 2. Davies-Bouldin Index (DBI) Plot

# %%
plt.figure(figsize=(8, 5))
plt.plot(list(metrics["dbi"].keys()), list(metrics["dbi"].values()), marker="o", linestyle="dashed", color="red")
plt.xlabel("Number of Clusters")
plt.ylabel("Davies-Bouldin Index (DBI)")
plt.title("DBI vs. Number of Clusters (Batch Processing)")
plt.show()

# %% [markdown]
# ### 3. Calinski-Harabasz Index (CHI) Plot

# %%
plt.figure(figsize=(8, 5))
plt.plot(list(metrics["chi"].keys()), list(metrics["chi"].values()), marker="o", linestyle="dashed", color="green")
plt.xlabel("Number of Clusters")
plt.ylabel("Calinski-Harabasz Index (CHI)")
plt.title("CHI vs. Number of Clusters (Batch Processing)")
plt.show()

# %% [markdown]
# ### 4. WCSS (Elbow Method) Plot

# %%
plt.figure(figsize=(8, 5))
plt.plot(list(metrics["wcss"].keys()), list(metrics["wcss"].values()), marker="o", linestyle="dashed", color="purple")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS (Inertia)")
plt.title("Elbow Method - WCSS vs. Number of Clusters (Batch Processing)")
plt.show()

# %% [markdown]
# ### 5. Cophenetic Correlation Coefficient (CCC) Analysis
#
# The **Cophenetic Correlation Coefficient (CCC)** measures how well hierarchical clustering preserves the original pairwise distances.

# %%
print(f"Average Cophenetic Correlation Coefficient (CCC): {metrics['ccc']:.4f}")
# Out:
# Average Cophenetic Correlation Coefficient (CCC): 0.6836

# %%
sample_size = 5000  
subset_indices = np.random.choice(umap_reduced.shape[0], sample_size, replace=False)
subset = umap_reduced[subset_indices]

for linkage in ["ward", "average", "complete", "single"]:
    hac = AgglomerativeClustering(n_clusters=9, linkage=linkage)
    labels = hac.fit_predict(subset)
    sil_score = silhouette_score(subset, labels)
    print(f"Linkage: {linkage}, Silhouette Score: {sil_score:.3f}")


#optimal_k = 9
#hac = AgglomerativeClustering(n_clusters=optimal_k, linkage="ward")

#final_labels = hac.fit_predict(subset)

# Visualize final clusters (using t-SNE or PCA)
plt.figure(figsize=(8, 5))
sns.scatterplot(x=subset[:, 0], y=subset[:, 1], hue=labels, palette="viridis")
plt.xlabel("UMAP Component 1")
plt.ylabel("UMAP Component 2")
plt.title(f"Final Clustering with HAC (n_clusters={9})")
plt.legend(title="Cluster")
plt.show()
# Out:
# Linkage: ward, Silhouette Score: 0.290
# Linkage: average, Silhouette Score: 0.268
# Linkage: complete, Silhouette Score: 0.212
# Linkage: single, Silhouette Score: -0.512

# %%
from sklearn.metrics import silhouette_score

sil_score = silhouette_score(subset, labels)
print(f"Silhouette Score: {sil_score:.3f}")
# Out:
# Silhouette Score: -0.512
